# %% [markdown]
# <center><h1>Ejercicio N°5</h1></center><br>
# <b style="font-size:15px">Crear una función que devuelva un mapa de calor con la correlación
# de todas las variables numéricas (incluye las generadas), para cada
# país.
# </b>
# 	<ul>
# 		<li>La función debe contar con su respectiva documentación</li>
# 	</ul>
#
# --------
#
# Estudiante: Ing. Daniel Ali ALviarez Arvelay
#
# Tefl. +58 412-8970997
#
# linkedIn: https://www.linkedin.com/in/daniel-alviarez/
#
# Email: alviarezali4@gmail.com
#
# ----------------

# %%
#Importamos las librerias necesarias
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# Importamos el conjunto de datos que Utilizaremos para testear la funcion
df = pd.read_csv("autos_1.csv")
df["Si var 1 > var 2 → 5, caso contrario 3"] = df["Si var 1 > var 2 → 5, caso contrario 3"].astype(str)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394 entries, 0 to 393
# Data columns (total 15 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Unnamed: 0                              394 non-null    int64
#  1   Millas_Por_Galon                        394 non-null    float64
#  2   Cilindros                               394 non-null    int64
#  3   Pais_Origen                             394 non-null    object
#  4   Peso_En_Libras                          394 non-null    int64
#  5   Desplazamiento                          394 non-null    float64
#  6   Aceleracion                             394 non-null    float64
#  7   Nombre                                  394 non-null    object
#  8   Anyo                                    394 non-null    object
#  9   Caballo_De_Fuerza                       394 non-null    float64
# ...

# %%
def corr_df (df, col_country):
    '''Recibe un DataFrame y un valor en formato String de la variable a estudiar. 
    
    Esta funcion devuelve un mapa de calor con la correlacion de todas las variables numericas incluidas en el DataFrame
    
    Return: None
    '''
    
    #Agrupa los datos por Pais
    byCountry = df.groupby("Pais_Origen")
    
    #Selecciono las variables numericas del DataFrame
    num_cols = df.describe().columns.to_list()
    
    #Se crea un mapa de calor para cada pais presente.
    for country, data in byCountry:

        plt.figure(figsize=(10,5))
        corr = data[num_cols].corr()
        sns.heatmap(corr, cmap="coolwarm", annot=True, mask=np.tril(np.ones_like(corr, dtype=bool)))
        plt.tight_layout()
        plt.title(f"Tabla de correlacion para {country}")

# %%
#LLamo a mi funcion
corr_df(df, "Pais_Origen")
